# %%
import pandas as pd

# %%
root = "../../"

bin_ind = "pickles/binary/hold_out/label_independent/"
bin_dep = "pickles/binary/hold_out/label_dependent/"

mul_ind = "pickles/multiclass_categorical/hold_out/label_independent/"
mul_dep = "pickles/multiclass_categorical/hold_out/label_dependent/"

ovo_ind = "pickles/multiclass_one_vs_one/hold_out/label_independent/"
ovo_dep = "pickles/multiclass_one_vs_one/hold_out/label_dependent/"

ovr_ind = "pickles/multiclass_one_vs_rest/hold_out/label_independent/"
ovr_dep = "pickles/multiclass_one_vs_rest/hold_out/label_dependent/"

# %% [markdown]
# ___
#
# # Loading Data

# %% [markdown]
# ### Binary Classifiers

# %%
bin_list = []
bin_list.append(pd.read_pickle(root + bin_ind + "pre.pkl"))
bin_list.append(pd.read_pickle(root + bin_ind + "basic.pkl"))
bin_list.append(pd.read_pickle(root + bin_ind + "corr.pkl"))

bin_list.append(pd.read_pickle(root + bin_dep + "anova.pkl"))
bin_list.append(pd.read_pickle(root + bin_dep + "mutual_info.pkl"))
bin_list.append(pd.read_pickle(root + bin_dep + "relieff.pkl"))
bin_list.append(pd.read_pickle(root + bin_dep + "xgb_gain.pkl"))
bin_list.append(pd.read_pickle(root + bin_dep + "wrfs.pkl"))
bin_list.append(pd.read_pickle(root + bin_dep + "rfe.pkl"))

# %%
pd.concat(bin_list)
# Out:
#                Method  Accuracy Precision Recall  F1_Score  Fit_Time  \
# 0       Preprocessing  0.998106  0.996226    1.0  0.998110  0.402000
# 0       Basic_Methods  0.998106  0.996226    1.0  0.998110  0.361994
# 0         Correlation  0.998106  0.996226    1.0  0.998110  0.344000
# 0               ANOVA  1.000000  1.000000    1.0  1.000000  0.204001
# 0  Mutual Information  0.998106  0.996226    1.0  0.998110  1.661996
# 0             ReliefF  0.996212  0.992481    1.0  0.996226  1.415000
# 0        XGBoost Gain  0.998106  0.996226    1.0  0.998110  0.544994
# 0            Ensemble  1.000000  1.000000    1.0  1.000000  3.394994
# 0                 RFE  1.000000  1.000000    1.0  1.000000  8.038990
#
#     FS_Time Train_Time Input_Features Output_Features
# 0         0   0.402000             86              77
# 0  0.019000   0.342995             77              63
# 0  0.076010   0.267990             63              42
# 0  0.011000   0.193001             40              20
# ...

# %% [markdown]
# ### Multiclass Classifiers (Categorical Cross Entropy)

# %%
mul_list = []
mul_list.append(pd.read_pickle(root + mul_ind + "pre.pkl"))
mul_list.append(pd.read_pickle(root + mul_ind + "basic.pkl"))
mul_list.append(pd.read_pickle(root + mul_ind + "corr.pkl"))

mul_list.append(pd.read_pickle(root + mul_dep + "anova.pkl"))
mul_list.append(pd.read_pickle(root + mul_dep + "mutual_info.pkl"))
mul_list.append(pd.read_pickle(root + mul_dep + "relieff.pkl"))
mul_list.append(pd.read_pickle(root + mul_dep + "xgb_gain.pkl"))
mul_list.append(pd.read_pickle(root + mul_dep + "wrfs.pkl"))
mul_list.append(pd.read_pickle(root + mul_dep + "rfe.pkl"))

# %%
pd.concat(mul_list)
# Out:
#                Method  Accuracy Precision    Recall  F1_Score   Fit_Time  \
# 0       Preprocessing  0.731061  0.729548  0.731061  0.720807   5.317004
# 0       Basic_Methods  0.731061  0.729548  0.731061  0.720807   4.798003
# 0         Correlation  0.740530  0.739516  0.740530  0.728800   3.136010
# 0               ANOVA  0.721591  0.725369  0.721591  0.710557   2.422000
# 0  Mutual Information  0.731061  0.730900  0.731061  0.719758   4.422004
# 0             ReliefF  0.712121  0.723404  0.712121  0.694824   3.544999
# 0        XGBoost Gain  0.715909  0.720729  0.715909  0.703391   7.542996
# 0            Ensemble  0.719697  0.724781  0.719697  0.707310   9.735003
# 0                 RFE  0.715909  0.720036  0.715909  0.702948  74.783010
#
#      FS_Time Train_Time Input_Features Output_Features
# 0          0   5.317004             86              77
# 0   0.017003   4.781000             77              61
# 0   0.073002   3.063008             61              35
# ...

# %% [markdown]
# ### Multiclass Classifiers (One vs One)

# %%
ovo_list = []
ovo_list.append(pd.read_pickle(root + ovo_ind + "pre.pkl"))
ovo_list.append(pd.read_pickle(root + ovo_ind + "basic.pkl"))
ovo_list.append(pd.read_pickle(root + ovo_ind + "corr.pkl"))

ovo_list.append(pd.read_pickle(root + ovo_dep + "anova.pkl"))
ovo_list.append(pd.read_pickle(root + ovo_dep + "mutual_info.pkl"))
ovo_list.append(pd.read_pickle(root + ovo_dep + "relieff.pkl"))
ovo_list.append(pd.read_pickle(root + ovo_dep + "xgb_gain.pkl"))
ovo_list.append(pd.read_pickle(root + ovo_dep + "wrfs.pkl"))
ovo_list.append(pd.read_pickle(root + ovo_dep + "rfe.pkl"))

# %%
pd.concat(ovo_list)
# Out:
#                Method  Accuracy Precision    Recall  F1_Score   Fit_Time  \
# 0       Preprocessing  0.740530  0.741742  0.740530  0.730063   7.544997
# 0       Basic_Methods  0.740530  0.741742  0.740530  0.730063   7.287995
# 0         Correlation  0.744318  0.747879  0.744318  0.734853   6.588996
# 0               ANOVA  0.715909  0.715601  0.715909  0.704428   5.380995
# 0  Mutual Information  0.738636  0.740444  0.738636  0.729004   7.829000
# 0             ReliefF  0.706439  0.711723  0.706439  0.688395   6.923990
# 0        XGBoost Gain  0.721591  0.725854  0.721591  0.710447  11.074990
# 0            Ensemble  0.725379  0.729644  0.725379  0.714235  12.986992
# 0                 RFE  0.719697  0.723383  0.719697  0.707585  78.085993
#
#      FS_Time Train_Time Input_Features Output_Features
# 0          0   7.544997             86              77
# 0   0.018000   7.269995             77              61
# 0   0.080002   6.508994             61              35
# ...

# %% [markdown]
# ### Multiclass Classifiers (One vs Rest)

# %%
ovr_list = []
ovr_list.append(pd.read_pickle(root + ovr_ind + "pre.pkl"))
ovr_list.append(pd.read_pickle(root + ovr_ind + "basic.pkl"))
ovr_list.append(pd.read_pickle(root + ovr_ind + "corr.pkl"))

ovr_list.append(pd.read_pickle(root + ovr_dep + "anova.pkl"))
ovr_list.append(pd.read_pickle(root + ovr_dep + "mutual_info.pkl"))
ovr_list.append(pd.read_pickle(root + ovr_dep + "relieff.pkl"))
ovr_list.append(pd.read_pickle(root + ovr_dep + "xgb_gain.pkl"))
ovr_list.append(pd.read_pickle(root + ovr_dep + "wrfs.pkl"))
ovr_list.append(pd.read_pickle(root + ovr_dep + "rfe.pkl"))

# %%
pd.concat(ovr_list)
# Out:
#                Method  Accuracy Precision    Recall  F1_Score   Fit_Time  \
# 0       Preprocessing  0.740530  0.740498  0.740530  0.728200   7.610002
# 0       Basic_Methods  0.740530  0.740498  0.740530  0.728200   7.429997
# 0         Correlation  0.736742  0.738319  0.736742  0.724470   4.396002
# 0               ANOVA  0.719697  0.720980  0.719697  0.708374   3.336993
# 0  Mutual Information  0.738636  0.737646  0.738636  0.725696   5.056992
# 0             ReliefF  0.712121  0.718432  0.712121  0.694814   4.003999
# 0        XGBoost Gain  0.723485  0.729764  0.723485  0.711870   8.015990
# 0            Ensemble  0.723485  0.727361  0.723485  0.711679  10.513992
# 0                 RFE  0.723485  0.731717  0.723485  0.711275  75.669993
#
#      FS_Time Train_Time Input_Features Output_Features
# 0          0   7.610002             86              77
# 0   0.020002   7.409995             77              61
# 0   0.075000   4.321002             61              35
# ...
