# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")

# %% [markdown]
# ___
#
# # Loading Data

# %% [markdown]
# ### Binary Classifiers

# %%
b_pfm_pre = pd.read_pickle("../../pickles/binary/pfm_pre.pkl")
b_pfm_basic = pd.read_pickle("../../pickles/binary/pfm_basic.pkl")
b_pfm_corr = pd.read_pickle("../../pickles/binary/pfm_corr.pkl")

# %% [markdown]
# ### Multiclass Classifiers (Categorical Cross Entropy)

# %%
m_cat_pfm_pre = pd.read_pickle("../../pickles/multiclass_categorical/pfm_pre.pkl")
m_cat_pfm_basic = pd.read_pickle("../../pickles/multiclass_categorical/pfm_basic.pkl")
m_cat_pfm_corr = pd.read_pickle("../../pickles/multiclass_categorical/pfm_corr.pkl")

# %% [markdown]
# ### Multiclass Classifiers (One vs One)

# %%
m_ovo_pfm_pre = pd.read_pickle("../../pickles/multiclass_one_vs_one/pfm_pre.pkl")
m_ovo_pfm_basic = pd.read_pickle("../../pickles/multiclass_one_vs_one/pfm_basic.pkl")
m_ovo_pfm_corr = pd.read_pickle("../../pickles/multiclass_one_vs_one/pfm_corr.pkl")

# %% [markdown]
# ### Multiclass Classifiers (One vs Rest)

# %%
m_ovr_pfm_pre = pd.read_pickle("../../pickles/multiclass_one_vs_rest/pfm_pre.pkl")
m_ovr_pfm_basic = pd.read_pickle("../../pickles/multiclass_one_vs_rest/pfm_basic.pkl")
m_ovr_pfm_corr = pd.read_pickle("../../pickles/multiclass_one_vs_rest/pfm_corr.pkl")

# %% [markdown]
# ___
#
# # Graphs

# %% [markdown]
# ### Helper Function

# %%
def load_metric(classifier, metric):
    if classifier == "Binary":
        metrics = pd.DataFrame([b_pfm_pre[metric],
                            b_pfm_basic[metric],
                            b_pfm_corr[metric]])
    elif classifier == "Multiclass":
        metrics = pd.DataFrame([m_cat_pfm_pre[metric],
                            m_cat_pfm_basic[metric],
                            m_cat_pfm_corr[metric]])
    elif classifier == "OvO":
        metrics = pd.DataFrame([m_ovo_pfm_pre[metric],
                            m_ovo_pfm_basic[metric],
                            m_ovo_pfm_corr[metric]])
    else:
        metrics = pd.DataFrame([m_ovr_pfm_pre[metric],
                            m_ovr_pfm_basic[metric],
                            m_ovr_pfm_corr[metric]])

    metrics = metrics.T
    metrics.columns = ["Preprocessing", "Basic_Methods", "Correlation"]

    return metrics

# %% [markdown]
# ## Accuracy

# %%
b_accuracies = load_metric("Binary", "Accuracy")
m_cat_accuracies = load_metric("Multiclass", "Accuracy")
m_ovo_accuracies = load_metric("OvO", "Accuracy")
m_ovr_accuracies = load_metric("OvR", "Accuracy")

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Accuracy')

sns.boxplot(ax = axes[0, 0], data=b_accuracies)
axes[0, 0].set_title('Binary Classifiers')

sns.boxplot(ax = axes[0, 1], data=m_cat_accuracies)
axes[0, 1].set_title('Multiclass Classifiers')

sns.boxplot(ax = axes[1, 0], data=m_ovo_accuracies)
axes[1, 0].set_title('Multiclass Classifiers (OvO)')

sns.boxplot(ax = axes[1, 1], data=m_ovr_accuracies)
axes[1, 1].set_title('Multiclass Classifiers (OvR)')

fig.tight_layout()

# %% [markdown]
# ## Precision

# %%
b_precisions = load_metric("Binary", "Precision")
m_cat_precisions = load_metric("Multiclass", "Precision")
m_ovo_precisions = load_metric("OvO", "Precision")
m_ovr_precisions = load_metric("OvR", "Precision")

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Precision')

sns.boxplot(ax = axes[0, 0], data=b_precisions)
axes[0, 0].set_title('Binary Classifiers')

sns.boxplot(ax = axes[0, 1], data=m_cat_precisions)
axes[0, 1].set_title('Multiclass Classifiers')

sns.boxplot(ax = axes[1, 0], data=m_ovo_precisions)
axes[1, 0].set_title('Multiclass Classifiers (OvO)')

sns.boxplot(ax = axes[1, 1], data=m_ovr_precisions)
axes[1, 1].set_title('Multiclass Classifiers (OvR)')

fig.tight_layout()

# %% [markdown]
# ## Recall

# %%
b_recalls = load_metric("Binary", "Recall")
m_cat_recalls = load_metric("Multiclass", "Recall")
m_ovo_recalls = load_metric("OvO", "Recall")
m_ovr_recalls = load_metric("OvR", "Recall")

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Recall')

sns.boxplot(ax = axes[0, 0], data=b_recalls)
axes[0, 0].set_title('Binary Classifiers')

sns.boxplot(ax = axes[0, 1], data=m_cat_recalls)
axes[0, 1].set_title('Multiclass Classifiers')

sns.boxplot(ax = axes[1, 0], data=m_ovo_recalls)
axes[1, 0].set_title('Multiclass Classifiers (OvO)')

sns.boxplot(ax = axes[1, 1], data=m_ovr_recalls)
axes[1, 1].set_title('Multiclass Classifiers (OvR)')

fig.tight_layout()

# %% [markdown]
# ## F1 Score

# %%
b_f1_scores = load_metric("Binary", "F1_Score")
m_cat_f1_scores = load_metric("Multiclass", "F1_Score")
m_ovo_f1_scores = load_metric("OvO", "F1_Score")
m_ovr_f1_scores = load_metric("OvR", "F1_Score")

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('F1 Score')

sns.boxplot(ax = axes[0, 0], data=b_f1_scores)
axes[0, 0].set_title('Binary Classifiers')

sns.boxplot(ax = axes[0, 1], data=m_cat_f1_scores)
axes[0, 1].set_title('Multiclass Classifiers')

sns.boxplot(ax = axes[1, 0], data=m_ovo_f1_scores)
axes[1, 0].set_title('Multiclass Classifiers (OvO)')

sns.boxplot(ax = axes[1, 1], data=m_ovr_f1_scores)
axes[1, 1].set_title('Multiclass Classifiers (OvR)')

fig.tight_layout()

plt.savefig("../../pictures/vector/02_f1_independent.svg")

# %% [markdown]
# ___

# %% [markdown]
# ## Fit Times

# %%
b_fit_times = load_metric("Binary", "Fit_Time")
m_cat_fit_times = load_metric("Multiclass", "Fit_Time")
m_ovo_fit_times = load_metric("OvO", "Fit_Time")
m_ovr_fit_times = load_metric("OvR", "Fit_Time")

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Fit Times')

sns.boxplot(ax = axes[0, 0], data=b_fit_times)
axes[0, 0].set_title('Binary Classifiers')

sns.boxplot(ax = axes[0, 1], data=m_cat_fit_times)
axes[0, 1].set_title('Multiclass Classifiers')

sns.boxplot(ax = axes[1, 0], data=m_ovo_fit_times)
axes[1, 0].set_title('Multiclass Classifiers (OvO)')

sns.boxplot(ax = axes[1, 1], data=m_ovr_fit_times)
axes[1, 1].set_title('Multiclass Classifiers (OvR)')

fig.tight_layout()

# %% [markdown]
# ## Feature Selection vs Training Times

# %%
bin_times = pd.DataFrame()
bin_times["Feature Selection"] = load_metric("Binary", "FS_Time").mean()
bin_times["Classifier Training"] = load_metric("Binary", "Train_Time").mean()
multi_times = pd.DataFrame()
multi_times["Feature Selection"] = load_metric("Multiclass", "FS_Time").mean()
multi_times["Classifier Training"] = load_metric("Multiclass", "Train_Time").mean()
multi_times = pd.DataFrame()
multi_times["Feature Selection"] = load_metric("Multiclass", "FS_Time").mean()
multi_times["Training"] = load_metric("Multiclass", "Train_Time").mean()
ovo_times = pd.DataFrame()
ovo_times["Feature Selection"] = load_metric("OvO", "FS_Time").mean()
ovo_times["Training"] = load_metric("OvO", "Train_Time").mean()
ovr_times = pd.DataFrame()
ovr_times["Feature Selection"] = load_metric("OvR", "FS_Time").mean()
ovr_times["Training"] = load_metric("OvR", "Train_Time").mean()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Feature Selection and Classifier Training Runtimes')

bin_times.plot.bar(ax = axes[0], stacked=True, rot=0)
axes[0].set_title('Binary Classifiers')
axes[0].set_ylabel('Runtime (seconds)')

multi_times.plot.bar(ax = axes[1], stacked=True, rot=0)
axes[1].set_title('Multiclass Classifiers')
axes[1].set_ylabel('Runtime (seconds)')

fig.tight_layout()
plt.savefig("../../pictures/vector/03_fit_times_share_independent.svg")

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Feature Selection and Training Times')

bin_times.plot.bar(ax = axes[0, 0], stacked=True, rot=0)
axes[0, 0].set_title('Binary Classifiers')

multi_times.plot.bar(ax = axes[0, 1], stacked=True, rot=0)
axes[0, 1].set_title('Multiclass Classifiers')

ovo_times.plot.bar(ax = axes[1, 0], stacked=True, rot=0)
axes[1, 0].set_title('Multiclass Classifiers (OvO)')

ovr_times.plot.bar(ax = axes[1, 1], stacked=True, rot=0)
axes[1, 1].set_title('Multiclass Classifiers (OvR)')

fig.tight_layout()

# %% [markdown]
# ## Predict Times

# %%
b_predict_times = load_metric("Binary", "Predict_Time")
m_cat_predict_times = load_metric("Multiclass", "Predict_Time")
m_ovo_predict_times = load_metric("OvO", "Predict_Time")
m_ovr_predict_times = load_metric("OvR", "Predict_Time")

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Batch Predict Times')

sns.boxplot(ax = axes[0, 0], data=b_predict_times)
axes[0, 0].set_title('Binary Classifiers')

sns.boxplot(ax = axes[0, 1], data=m_cat_predict_times)
axes[0, 1].set_title('Multiclass Classifiers')

sns.boxplot(ax = axes[1, 0], data=m_ovo_predict_times)
axes[1, 0].set_title('Multiclass Classifiers (OvO)')

sns.boxplot(ax = axes[1, 1], data=m_ovr_predict_times)
axes[1, 1].set_title('Multiclass Classifiers (OvR)')

fig.tight_layout()

# %% [markdown]
# ## Score Times

# %%
b_score_times = load_metric("Binary", "Score_Time")
m_cat_score_times = load_metric("Multiclass", "Score_Time")
m_ovo_score_times = load_metric("OvO", "Score_Time")
m_ovr_score_times = load_metric("OvR", "Score_Time")

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Score Times')

sns.boxplot(ax = axes[0, 0], data=b_score_times)
axes[0, 0].set_title('Binary Classifiers')

sns.boxplot(ax = axes[0, 1], data=m_cat_score_times)
axes[0, 1].set_title('Multiclass Classifiers')

sns.boxplot(ax = axes[1, 0], data=m_ovo_score_times)
axes[1, 0].set_title('Multiclass Classifiers (OvO)')

sns.boxplot(ax = axes[1, 1], data=m_ovr_score_times)
axes[1, 1].set_title('Multiclass Classifiers (OvR)')

fig.tight_layout()
